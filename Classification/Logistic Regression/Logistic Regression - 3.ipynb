# %%
import findspark
findspark.init('/home/aditya/spark-3.1.1-bin-hadoop2.7')
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Lreg").getOrCreate()

# %%
from pyspark.ml.classification import LogisticRegression

# %%
df = spark.read.csv('churn.csv', inferSchema=True, header=True)

# %%
df.printSchema()
# Out:
# root
#  |-- State: string (nullable = true)
#  |-- Account Length: integer (nullable = true)
#  |-- Area Code: integer (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- Int'l Plan: string (nullable = true)
#  |-- VMail Plan: string (nullable = true)
#  |-- VMail Message: integer (nullable = true)
#  |-- Day Mins: double (nullable = true)
#  |-- Day Calls: integer (nullable = true)
#  |-- Day Charge: double (nullable = true)
#  |-- Eve Mins: double (nullable = true)
#  |-- Eve Calls: integer (nullable = true)
#  |-- Eve Charge: double (nullable = true)
#  |-- Night Mins: double (nullable = true)
#  |-- Night Calls: integer (nullable = true)
#  |-- Night Charge: double (nullable = true)
#  |-- Intl Mins: double (nullable = true)
#  |-- Intl Calls: integer (nullable = true)
#  |-- Intl Charge: double (nullable = true)
#  |-- CustServ Calls: integer (nullable = true)
#  |-- Churn?: string (nullable = true)

# %%
from pyspark.sql.functions import countDistinct
for col in df.columns:
    df.select(col).describe().show()
    df.select(countDistinct(col)).show()
# Out:
# +-------+-----+
# |summary|State|
# +-------+-----+
# |  count| 3333|
# |   mean| null|
# | stddev| null|
# |    min|   AK|
# |    max|   WY|
# +-------+-----+
#
# +---------------------+
# |count(DISTINCT State)|
# +---------------------+
# |                   51|
# +---------------------+
#
# +-------+------------------+
# |summary|    Account Length|
# +-------+------------------+
# |  count|              3333|
# |   mean|101.06480648064806|
# | stddev|39.822105928595676|
# |    min|                 1|
# |    max|               243|
# +-------+------------------+
#
# +------------------------------+
# |count(DISTINCT Account Length)|
# +------------------------------+
# |                           212|
# +------------------------------+
#
# +-------+------------------+
# |summary|         Area Code|
# +-------+------------------+
# |  count|              3333|
# |   mean|437.18241824182417|
# | stddev| 42.37129048560661|
# |    min|               408|
# |    max|               510|
# +-------+------------------+
#
# +-------------------------+
# |count(DISTINCT Area Code)|
# +-------------------------+
# |                        3|
# +-------------------------+
#
# +-------+--------+
# |summary|   Phone|
# +-------+--------+
# |  count|    3333|
# |   mean|    null|
# | stddev|    null|
# |    min|327-1058|
# |    max|422-9964|
# +-------+--------+
#
# +---------------------+
# |count(DISTINCT Phone)|
# +---------------------+
# |                 3333|
# +---------------------+
#
# +-------+----------+
# |summary|Int'l Plan|
# +-------+----------+
# |  count|      3333|
# |   mean|      null|
# | stddev|      null|
# |    min|        no|
# |    max|       yes|
# +-------+----------+
#
# +--------------------------+
# |count(DISTINCT Int'l Plan)|
# +--------------------------+
# |                         2|
# +--------------------------+
#
# +-------+----------+
# |summary|VMail Plan|
# +-------+----------+
# |  count|      3333|
# |   mean|      null|
# | stddev|      null|
# |    min|        no|
# |    max|       yes|
# +-------+----------+
#
# +--------------------------+
# |count(DISTINCT VMail Plan)|
# +--------------------------+
# |                         2|
# +--------------------------+
#
# +-------+------------------+
# |summary|     VMail Message|
# +-------+------------------+
# |  count|              3333|
# |   mean| 8.099009900990099|
# | stddev|13.688365372038598|
# |    min|                 0|
# |    max|                51|
# +-------+------------------+
#
# +-----------------------------+
# |count(DISTINCT VMail Message)|
# +-----------------------------+
# |                           46|
# +-----------------------------+
#
# +-------+------------------+
# |summary|          Day Mins|
# +-------+------------------+
# |  count|              3333|
# |   mean|179.77509750975116|
# | stddev| 54.46738920237146|
# |    min|               0.0|
# |    max|             350.8|
# +-------+------------------+
#
# +------------------------+
# |count(DISTINCT Day Mins)|
# +------------------------+
# |                    1667|
# +------------------------+
#
# +-------+------------------+
# |summary|         Day Calls|
# +-------+------------------+
# |  count|              3333|
# |   mean|100.43564356435644|
# | stddev|20.069084207300893|
# |    min|                 0|
# |    max|               165|
# +-------+------------------+
#
# +-------------------------+
# |count(DISTINCT Day Calls)|
# +-------------------------+
# |                      119|
# +-------------------------+
#
# +-------+------------------+
# |summary|        Day Charge|
# +-------+------------------+
# |  count|              3333|
# |   mean|30.562307230723093|
# | stddev| 9.259434553930495|
# |    min|               0.0|
# |    max|             59.64|
# +-------+------------------+
#
# +--------------------------+
# |count(DISTINCT Day Charge)|
# +--------------------------+
# |                      1667|
# +--------------------------+
#
# +-------+------------------+
# |summary|          Eve Mins|
# +-------+------------------+
# |  count|              3333|
# |   mean|200.98034803480346|
# | stddev|50.713844425811985|
# |    min|               0.0|
# |    max|             363.7|
# +-------+------------------+
#
# +------------------------+
# |count(DISTINCT Eve Mins)|
# +------------------------+
# |                    1611|
# +------------------------+
#
# +-------+------------------+
# |summary|         Eve Calls|
# +-------+------------------+
# |  count|              3333|
# |   mean|100.11431143114311|
# | stddev| 19.92262529394312|
# |    min|                 0|
# |    max|               170|
# +-------+------------------+
#
# +-------------------------+
# |count(DISTINCT Eve Calls)|
# +-------------------------+
# |                      123|
# +-------------------------+
#
# +-------+------------------+
# |summary|        Eve Charge|
# +-------+------------------+
# |  count|              3333|
# |   mean|17.083540354035392|
# | stddev| 4.310667643110347|
# |    min|               0.0|
# |    max|             30.91|
# +-------+------------------+
#
# +--------------------------+
# |count(DISTINCT Eve Charge)|
# +--------------------------+
# |                      1440|
# +--------------------------+
#
# +-------+------------------+
# |summary|        Night Mins|
# +-------+------------------+
# |  count|              3333|
# |   mean|200.87203720372048|
# | stddev| 50.57384701365836|
# |    min|              23.2|
# |    max|             395.0|
# +-------+------------------+
#
# +--------------------------+
# |count(DISTINCT Night Mins)|
# +--------------------------+
# |                      1591|
# +--------------------------+
#
# +-------+------------------+
# |summary|       Night Calls|
# +-------+------------------+
# |  count|              3333|
# |   mean|100.10771077107711|
# | stddev|19.568609346058544|
# |    min|                33|
# |    max|               175|
# +-------+------------------+
#
# +---------------------------+
# |count(DISTINCT Night Calls)|
# +---------------------------+
# |                        120|
# +---------------------------+
#
# +-------+-----------------+
# |summary|     Night Charge|
# +-------+-----------------+
# |  count|             3333|
# |   mean|9.039324932493264|
# | stddev|2.275872837660027|
# |    min|             1.04|
# |    max|            17.77|
# +-------+-----------------+
#
# +----------------------------+
# |count(DISTINCT Night Charge)|
# +----------------------------+
# |                         933|
# +----------------------------+
#
# +-------+------------------+
# |summary|         Intl Mins|
# +-------+------------------+
# |  count|              3333|
# |   mean|10.237293729372933|
# | stddev| 2.791839548408416|
# |    min|               0.0|
# |    max|              20.0|
# +-------+------------------+
#
# +-------------------------+
# |count(DISTINCT Intl Mins)|
# +-------------------------+
# |                      162|
# +-------------------------+
#
# +-------+------------------+
# |summary|        Intl Calls|
# +-------+------------------+
# |  count|              3333|
# |   mean|4.4794479447944795|
# | stddev|2.4612142705460953|
# |    min|                 0|
# |    max|                20|
# +-------+------------------+
#
# +--------------------------+
# |count(DISTINCT Intl Calls)|
# +--------------------------+
# |                        21|
# +--------------------------+
#
# +-------+------------------+
# |summary|       Intl Charge|
# +-------+------------------+
# |  count|              3333|
# |   mean| 2.764581458145804|
# | stddev|0.7537726126630451|
# |    min|               0.0|
# |    max|               5.4|
# +-------+------------------+
#
# +---------------------------+
# |count(DISTINCT Intl Charge)|
# +---------------------------+
# |                        162|
# +---------------------------+
#
# +-------+------------------+
# |summary|    CustServ Calls|
# +-------+------------------+
# |  count|              3333|
# |   mean|1.5628562856285628|
# | stddev|1.3154910448664752|
# |    min|                 0|
# |    max|                 9|
# +-------+------------------+
#
# +------------------------------+
# |count(DISTINCT CustServ Calls)|
# +------------------------------+
# |                            10|
# +------------------------------+
#
# +-------+------+
# |summary|Churn?|
# +-------+------+
# |  count|  3333|
# |   mean|  null|
# | stddev|  null|
# |    min|False.|
# |    max| True.|
# +-------+------+
#
# +----------------------+
# |count(DISTINCT Churn?)|
# +----------------------+
# |                     2|
# +----------------------+

# %%
mydf = df.select(['State', 'Account Length', 'Area Code', "Int'l Plan", 'VMail Plan',
 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge', 'Eve Mins', 'Eve Calls',
 'Eve Charge', 'Night Mins', 'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls',
 'Intl Charge', 'CustServ Calls', 'Churn?'])
myfinaldf = mydf.na.drop()

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler

state_indexer = StringIndexer(inputCol='State',outputCol='StateIndexed')
state_encoder = OneHotEncoder(inputCol='StateIndexed',outputCol='stateVec')

area_indexer = StringIndexer(inputCol='Area Code',outputCol='AreaIndexed')
area_encoder = OneHotEncoder(inputCol='AreaIndexed',outputCol='areaVec')

int_plan_indexer = StringIndexer(inputCol="Int'l Plan",outputCol='IntplanIndexed')
# int_plan_encoder = OneHotEncoder(inputCol='IntplanIndexed',outputCol='IntPlanVec')

vmail_indexer = StringIndexer(inputCol="VMail Plan",outputCol='vmailIndexed')
# vmail_encoder = OneHotEncoder(inputCol='vmailIndexed',outputCol='vmailVec')

churn_indexer = StringIndexer(inputCol="Churn?",outputCol='ChurnIndexed')


assembler = VectorAssembler(inputCols=['stateVec', 'Account Length', 'areaVec', 
                                       "IntplanIndexed", 'vmailIndexed',
 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge', 'Eve Mins', 'Eve Calls',
 'Eve Charge', 'Night Mins', 'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls',
 'Intl Charge', 'CustServ Calls'], outputCol='features')

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline

# %%
log_reg = LogisticRegression(featuresCol='features',labelCol='ChurnIndexed')

# %%
mlpipeline = Pipeline(stages=[state_indexer,state_encoder,area_indexer,area_encoder,
                              int_plan_indexer,vmail_indexer,
                             churn_indexer,assembler, log_reg])

# %%
##split data into train and test
train_data, test_data = myfinaldf.randomSplit([0.7,0.3])

# %%
mymodel = mlpipeline.fit(train_data)

# %%
results = mymodel.transform(test_data)

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# %%
myeval = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction",
                                      labelCol='ChurnIndexed')

# %%
myeval.evaluate(results)
# Out:
# 0.7866068149357215
